# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\theha\AppData\Local\Temp\ipykernel_23988\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("flight_price (1).xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# ## Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
# ## Answer

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# - Rows : 10683
# - Columns : 11

# %% [markdown]
# ##

# %% [markdown]
# ## Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
# ## Answer

# %%
plt.figure(figsize=(12,7))
sns.histplot(data = df, x="Price", kde=True, fill=True)
plt.xlabel("Price distribution")
plt.show()

# %% [markdown]
# - The Flight Price Distribution is Right Skewed in the datasheet.

# %% [markdown]
# ##

# %% [markdown]
# ## Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
# ## Answer

# %%
range = df["Price"].min(), df["Price"].max()
print("The range of flight price dataset is",range)
# Out:
# The range of flight price dataset is (1759, 79512)

# %% [markdown]
# ##

# %% [markdown]
# ## Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.
# ## Answer

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=df, x="Airline", y="Price")
plt.title("Price Distribution wrt Airline")
plt.xlabel("Airline")
plt.ylabel("Price")
plt.show()

# %%
cat = df["Airline"].unique()
categories = cat.tolist()
categories
# Out:
# ['IndiGo',
#  'Air India',
#  'Jet Airways',
#  'SpiceJet',
#  'Multiple carriers',
#  'GoAir',
#  'Vistara',
#  'Air Asia',
#  'Vistara Premium economy',
#  'Jet Airways Business',
#  'Multiple carriers Premium economy',
#  'Trujet']

# %%
for category in categories:
    plt.figure(figsize=(10,5))
    sns.histplot(data=df[df["Airline"]==category], x="Price")
    plt.title(category)
    plt.xlabel("Price Distribution")
    plt.show()

# %% [markdown]
# - The lowest Price is of INDIGO Airline
# - The Highest Price is of Jet Airways Business

# %%
df[df["Price"] > 70000]
# Out:
#                    Airline Date_of_Journey    Source Destination  \
# 2924  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                 Route Dep_Time Arrival_Time Duration Total_Stops  \
# 2924  BLR → BOM → DEL    05:45        11:25   5h 40m      1 stop
#
#      Additional_Info  Price
# 2924  Business class  79512

# %% [markdown]
# ##

# %% [markdown]
# ## Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
# ## Answer

# %% [markdown]
# #### Yes there are Outliers in our Flight Price Dataset, As we saw already in the last question we solved, there are many outliers in the price column for each Airline.

# %% [markdown]
# ### Impact of Outliers in our Analysis:
# - Outliers can distort statistical measures, such as the mean and standard deviation.
# - A single outlier can significantly shift the mean, leading to erroneous conclusions about data trends and behaviors.

# %% [markdown]
# ##

# %% [markdown]
# ## Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
# ## Answer

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# - To analyze or to identify the peak season when people travel the most, I'll use the Data of journey "Month".
# - To present my findings to the Authority, I will first distinct the Date of journey column into Day, Month and Year, and then i'll find the mode or the month in which people travel the most.

# %% [markdown]
# ##

# %% [markdown]
# ## Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
# ## Answer

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882

# %% [markdown]
# ### Features i would analyze to identify the trends are :
# - Airline
# - Date_of_Journey
# - Source

# %% [markdown]
# ### Visualizations i would use to present my findings to my team are :
# - Price Trends in different Airlines
# - Price trends in different months and wrt to Airline
# - Price Trends on different Source locations and wrt Airline and wrt different months.

# %% [markdown]
# ##

# %% [markdown]
# ## Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
# ## Answer

# %% [markdown]
# ### There are 3 features from the dataset i'll use to analyze the factors that affect the flight prices :
# - Data of Journey
# - Airline

# %% [markdown]
# #### Date of Journey :
# - Months can affect the Flight Prices based on the people travel ratio in that month.
# ###
# #### Airline :
# - For the same destination, Different Airlines can have different flight price.

# %% [markdown]
# ##

# %% [markdown]
# ## GOOGLE PLAY STORE

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv")
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?
# ## Answer

# %%
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# - The Dataset has 10841 rows and 13 columns

# %% [markdown]
# ##

# %% [markdown]
# ##  Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.
# ## Answer

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data =df1, x="Category", y="Rating")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.ylabel("Rating")
plt.title("Ratings vary with Category")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(data =df1, x="Rating", hue="Category", color="b")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.ylabel("Rating")
plt.title("Ratings vary with Category")
plt.show()
# Out:
# C:\Users\theha\AppData\Local\Temp\ipykernel_23988\2989339825.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data =df1, x="Rating", hue="Category", color="b")

# %% [markdown]
# - All the category ratings are showing left skewed presentation.

# %% [markdown]
# ##

# %% [markdown]
# ##  Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.
# ## Answer

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# - Yes there are so many null values present in the dataset.
#     - 1474 in Ratings
#     - 1 in Type
#     - 8 in current ver
#     - 3 in android ver

# %% [markdown]
# - These null values can impact the performance of our model.
# - Imperfect Analysis

# %% [markdown]
# ##

# %% [markdown]
# ##  Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.
# ## Answer

# %%
new1 = df1[["Rating", "Size"]]

# %%
new1["Size"] = new1["Size"].str.replace(",", "")
new1["Size"] = new1["Size"].str.replace("+", "")
new1["Rating"] = new1["Rating"].replace(",", "")
new1["Rating"] = new1["Rating"].replace("+", "")

# %%
new1 = new1.dropna(axis=0)

# %%
new1[["Size","Rating" ]].corr()
# Out:
#             Size    Rating
# Size    1.000000  0.075741
# Rating  0.075741  1.000000

# %% [markdown]
# - both are very slightly correlating with each other, we can say they are not very much related to each other.

# %% [markdown]
# ##

# %% [markdown]
# ##  Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.
# ## Answer

# %%
df1["Price"] = df1["Price"].replace("$", np.nan)
df1["Price"] = df1["Price"].replace("Everyone", np.nan)

# %%
df1["Price"] = df1["Price"].astype(float)

# %%
plt.figure(figsize=(15,7))
sns.barplot(data =df1, x="Category", y="Price", hue="Category")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Finance lifestyle, Events, Family and medical Category charges the most
# - Beauty, Comics & House and Home are almost in free category

# %% [markdown]
# ##

# %% [markdown]
# ## Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.
# ## Answer

# %%
df1["Installs"] = df1["Installs"].str.replace("+", "")
df1["Installs"] = df1["Installs"].str.replace(",", "")
df1["Installs"] = df1["Installs"].replace("Free", np.nan)
df1["Installs"] = df1["Installs"].astype(float)

# %%
df1["Installs"] = df1["Installs"].dropna()

# %%
new0x = df1[["App", "Installs"]]

# %%
new0x = new0x.sort_values(by="Installs", ascending=False).head(10)

# %%
new0x
# Out:
#                                            App      Installs
# 3896                            Subway Surfers  1.000000e+09
# 382   Messenger – Text and Video Chat for Free  1.000000e+09
# 3234                                    Google  1.000000e+09
# 3232                        Google Street View  1.000000e+09
# 3223                 Maps - Navigate & Explore  1.000000e+09
# 468              Skype - free IM & video calls  1.000000e+09
# 1700                            Subway Surfers  1.000000e+09
# 3117                 Maps - Navigate & Explore  1.000000e+09
# 451                                      Gmail  1.000000e+09
# 411               Google Chrome: Fast & Secure  1.000000e+09

# %% [markdown]
# ##

# %% [markdown]
# ## Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company
# ## Answer

# %%
df1.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159   19M     10000.0  Free    0.0       Everyone
# 1     967   14M    500000.0  Free    0.0       Everyone
# 2   87510  8.7M   5000000.0  Free    0.0       Everyone
# 3  215644   25M  50000000.0  Free    0.0           Teen
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# ...

# %% [markdown]
# - The features i'll analyze to make recommendations to the company :
#     - Category
#     - Installs
#     - Rating
#     - Type
#     - Genre
#     - Content Rating

# %%
appCat = df1.groupby("Category")["Installs"].sum().reset_index()

# %%
appCat = appCat.sort_values(by="Installs", ascending=False)

# %%
appCat = appCat.head(10)
appCat
# Out:
#               Category      Installs
# 15                GAME  3.508602e+10
# 7        COMMUNICATION  3.264728e+10
# 26        PRODUCTIVITY  1.417609e+10
# 28              SOCIAL  1.406987e+10
# 30               TOOLS  1.145277e+10
# 12              FAMILY  1.025826e+10
# 25         PHOTOGRAPHY  1.008825e+10
# 22  NEWS_AND_MAGAZINES  7.496318e+09
# 31    TRAVEL_AND_LOCAL  6.868887e+09
# 32       VIDEO_PLAYERS  6.222003e+09

# %% [markdown]
# - The top 10 app Categories are above with the total number of their uploads around the world.

# %%
Cat = df1[df1["Category"]=="GAME"]

# %%
Cat["Type"].value_counts()
# Out:
# Type
# Free    1061
# Paid      83
# Name: count, dtype: int64

# %%
catEarn = df1.groupby("Category")["Price"].sum().reset_index()
catEarn = catEarn.sort_values(by="Price", ascending=False).head(10)
catEarn
# Out:
#            Category    Price
# 13          FINANCE  2900.83
# 12           FAMILY  2434.78
# 19        LIFESTYLE  2360.87
# 21          MEDICAL  1439.96
# 15             GAME   287.30
# 30            TOOLS   267.25
# 26     PRODUCTIVITY   250.93
# 5          BUSINESS   185.27
# 24  PERSONALIZATION   153.96
# 25      PHOTOGRAPHY   134.21

# %% [markdown]
# - These are the top 10 categories, which makes high profit

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df1, x="Category", hue="Content Rating")
plt.xlabel("Category")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - GAME & FAMILY audience is more than other categories.

# %% [markdown]
# #### In the same way, we can extract more insights from the data
