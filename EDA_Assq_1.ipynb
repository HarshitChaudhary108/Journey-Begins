# %% [markdown]
# ## Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in predicting the quality of wine.

# %% [markdown]
# ## Answer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\theha\AppData\Local\Temp\ipykernel_3740\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("WineQT.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# #### Alcohol: The most influential feature. Higher alcohol content often correlates with better quality.
# #### Volatile Acidity: Keep it within an acceptable range to avoid off-flavors.
# #### Chlorides: Balance saltiness for overall taste.
# #### SO₂ Levels: Maintain proper preservation without overuse.
# #### pH: Optimal acidity contributes to quality.

# %% [markdown]
# ##

# %% [markdown]
# ##  Q2. How did you handle missing data in the wine quality data set during the feature engineering process? Discuss the advantages and disadvantages of different imputation techniques.
# ## Answer

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# ### There can be many ways :
# #### 1. Remove the row or columns having missing values
# - Advantage : Easy to implement.
# - Disadvantage : This can cause intense data loss and get the performance of our model down.
# #### 2. Replacing mode with the missing values
# - Advantage : Simple and maintains sample size
# - Disadvantage : Ignores feature interactions
# #### K-Nearest Neighbors (KNN) Imputation:
# - Predicts missing values based on neighboring data points.
# - Advantage: Considers feature relationships.
# - Disadvantage: Computationally expensive.

# %% [markdown]
# ##

# %% [markdown]
# ## Q3. What are the key factors that affect students' performance in exams? How would you go about analyzing these factors using statistical techniques?
# ## Answer

# %%
df1 = pd.read_csv("StudentsPerformance.csv")
df1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# - Lunch
# - Parental Level of Education
# - Race/Ethnicity
# #### These Factors affect the students performance in exams

# %% [markdown]
# ##

# %% [markdown]
# ## Q4. Describe the process of feature engineering in the context of the student performance data set. How did you select and transform the variables for your model?
# ## Answer

# %%
df1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# #### Data Checks to perform always at first
# 1. Check Missing values
# 2. Check duplicates
# 3. Data type
# 4. Check the number of unique values of each column
# 5. Check statistics of data set
# 6. check various categories present in the different categories¶

# %% [markdown]
# ##

# %% [markdown]
# ## 5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to these features to improve normality?
# ## Answer

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
features = df.columns.tolist()
for feature in features:
    plt.figure(figsize=(7,2))
    sns.kdeplot(data=df, x=feature)
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# #### We can use many transformations to imprive the normality of the feature in a dataframe :
# - Log transformation
# - Square root transformation
# ##### and etc

# %% [markdown]
# ##

# %% [markdown]
# ## Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of features. What is the minimum number of principal components required to explain 90% of the variance in the data?
# ## Answer

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
scaled_data = minmax.fit_transform(df)

# %%
from sklearn.decomposition import PCA

# %%
instance = PCA(n_components=8)

# %%
data = instance.fit_transform(scaled_data)

# %%
data
# Out:
# array([[ 3.20801100e-01,  5.41190516e-01,  1.22194121e-01, ...,
#         -2.67034427e-02,  3.78412696e-02, -6.07127400e-02],
#        [ 3.34377561e-01,  5.07676389e-01,  4.35633360e-02, ...,
#          1.20199555e-02, -8.50104837e-02,  1.93182657e-01],
#        [ 3.51456781e-01,  4.59113592e-01,  9.09725333e-02, ...,
#          1.31035078e-02, -5.02057919e-02,  1.09702317e-01],
#        ...,
#        [-5.91297561e-01,  9.96088417e-02, -1.81533534e-01, ...,
#          2.47332066e-02,  8.85400488e-03, -1.36985146e-02],
#        [-6.21763466e-01, -5.39897503e-03, -3.19254314e-02, ...,
#         -6.58058929e-02,  7.58604830e-02, -1.21539318e-02],
#        [-5.82846004e-01,  1.14784500e-01, -1.98091014e-01, ...,
#          3.94006133e-04,  1.18532500e-01, -3.70258435e-02]])

# %%
scaled_data.shape
# Out:
# (1143, 13)

# %%
data.shape
# Out:
# (1143, 8)
